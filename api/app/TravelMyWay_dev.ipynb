# %%
import tmw_api_keys

ORS_api_key = tmw_api_keys.ORS_api_key
OuiBus_api_key = tmw_api_keys.OuiBus_api_key
SkyScanner_api_key = tmw_api_keys.SkyScanner_api_key
Navitia_api_key = tmw_api_keys.Navitia_api_key

# %% [markdown]
# # Initiate classes

# %%
class journey:
    def __init__(self, _id, steps=[]):
        self.id = _id
        self.label = ''
        self.score = 0
        self.total_distance = 0
        self.total_duration = 0
        self.total_price_EUR = 0
        self.total_gCO2 = 0
        self.steps = steps
    
    def add(self, steps=[]):
        self.steps.append(steps)
    
    def to_json(self):
        json = {'id':self.id,
                'label':self.label,
                'score':self.score,
                'total_distance':self.total_distance,
                'total_duration':self.total_duration,
                'total_price_EUR':self.total_price_EUR,
                'total_gCO2':self.total_gCO2,
                'journey':[step.to_json() for step in self.steps]
                }
        return json
    
    def reset(self):
        self.score = 0
        self.total_distance = 0
        self.total_duration = 0
        self.total_price_EUR = 0
        self.total_gCO2 = 0
    
    def update(self):
        self.score = 0
        self.total_distance = sum(filter(None,[step.distance_m for step in self.steps]))
        self.total_duration = sum(filter(None,[step.duration_s for step in self.steps]))
        self.total_price_EUR = sum(filter(None,[sum(step.price_EUR) for step in self.steps]))
        self.total_gCO2 = sum(filter(None,[step.gCO2 for step in self.steps]))
    
    def plot_map(self, center=(48.864716,2.349014), tiles = 'Stamen Toner', zoom_start = 10):
        import folium
        map_params = {'tiles':tiles,
              'location':center,
              'zoom_start': zoom_start}
        _map = folium.Map(**map_params)

        for step in self.steps:
            try:
                step.plot_map(center=center, _map=_map)
            except:
                print('ERROR plot map: step id: {} / type: {}'.format(step.id, step.type))
        return _map
    
class journey_step:
    def __init__(self, _id, _type, label='', distance_m=0, duration_s=0, price_EUR=[0.0], gCO2 = 0, geojson=''):
        self.id = _id
        self.type = _type
        self.label = label
        self.distance_m = distance_m
        self.duration_s = duration_s
        self.price_EUR = price_EUR
        self.gCO2 = gCO2
        self.geojson = geojson
        
    def to_json(self):
        json = {'id':self.id,
                 'type':self.type,
                 'label':self.label,
                 'distance_m':self.distance_m,
                 'duration_s':self.duration_s,
                 'price_EUR':self.price_EUR,
                 'gCO2':self.gCO2,
                 'geojson':self.geojson,
                }
        return json
    
    def init_map(self, center, tiles = 'Stamen Toner', zoom_start = 10):
        import folium
        map_params = {'tiles':tiles,
              'location':center,
              'zoom_start': zoom_start}
        _map = folium.Map(**map_params)
        return _map
    
    def plot_map(self, center=(48.864716,2.349014), _map=None):
        import folium
        _map = self.init_map(center) if _map == None else _map
        
        folium.features.GeoJson(data=self.geojson,
                        name=self.label,
                        overlay=True).add_to(_map)
        return _map

# %% [markdown]
# # Basic Functions

# %%
def geocode_address(address):
    '''
    address: string
    coord : [lon, lat]
    '''
    ORS_client = start_ORS_client()
    coord = ORS_client.pelias_search(address,size=1)['features'][0]['geometry']['coordinates']
    return coord

def create_query(start, to, datetime=''):
    json_query = {
        'query':{
            'start':{
                'address':start,
                'coord':geocode_address(start),  # [lon,lat]
            },
            'to':{
                'address':to,
                'coord':geocode_address(to),
            },
            'datetime':datetime          # example of format (based on navitia): 20191012T063700
            } 
    }
    return json_query

# %% [markdown]
# # OpenRouteService Functions

# %%
def start_ORS_client():
    import openrouteservice
    ORS_client = openrouteservice.Client(key=ORS_api_key) # Specify your personal API key
    return ORS_client

def ORS_profile(profile):
    dict_ORS_profile = {
        "driving-car":"car", 
        "driving-hgv":"", 
        "foot-walking":"walk",
        "foot-hiking":"walk", 
        "cycling-regular":"bike", 
        "cycling-road":"bike",
        "cycling-mountain":"bike",
        "cycling-electric":"bike"
    }
    return dict_ORS_profile[profile]

def ORS_query_directions(query, profile='driving-car', _id=0, geometry=True):
    '''
    profile= ["driving-car", "driving-hgv", "foot-walking","foot-hiking", "cycling-regular", "cycling-road","cycling-mountain",
    "cycling-electric",]
    '''
    from openrouteservice import convert
    
    ORS_client = start_ORS_client()
    coord = [query['query']['start']['coord'], query['query']['to']['coord'] ]
    ORS_step = ORS_client.directions(
        coord,
        profile=profile,
        instructions=False,
        geometry=geometry,
        )
    
    geojson = convert.decode_polyline(ORS_step['routes'][0]['geometry'])

    step = journey_step(_id, 
                        _type=ORS_profile(profile),
                        label=profile, 
                        distance_m=ORS_step['routes'][0]['summary']['distance'], 
                        duration_s=ORS_step['routes'][0]['summary']['duration'],
                        price_EUR=[0],
                        gCO2=0,
                        geojson=geojson,
                        )
    return step

# %% [markdown]
# # Navitia Functions

# %%
def start_navitia_client():
    from navitia_client import Client
    navitia_client = Client(user=Navitia_api_key)
    return navitia_client

def navitia_query_directions(query, _id=0):
    navitia_client = start_navitia_client()
    coord = [query['query']['start']['coord'], query['query']['to']['coord'] ]
    
    url = 'coverage/fr-idf/journeys?from={};{}&to={};{}'.format(coord[0][0],coord[0][1],coord[1][0],coord[1][1])
    urm = url + '&data_freshness=base_schedule&max_nb_journeys=3'
    step = navitia_client.raw(url, multipage=False)
 
    return step.json()

# %%
"""
https://doc.navitia.io/#journeys
type = 'waiting' / 'transfer' / 'public_transport' / 'street_network' / 'stay_in' / crow_fly
"""
def navitia_journeys(json, _id=0):
    # all journeys loop
    lst_journeys = list()
    for journey in json['journeys']:
        i = _id
        
        # journey loop
        lst_sections = list()
        for section in journey['sections']:

            try:
                lst_sections.append(navitia_journeys_sections_type(section, _id=i))
            except:
                print('ERROR : ')
                print('id: {}'.format(i))
                print(section)
            i = i+1
        lst_journeys.append(lst_sections)
    return lst_journeys

def navitia_journeys_sections_type(json, _id=0):
    switcher_journeys_sections_type = {
        'public_transport': navitia_journeys_sections_type_public_transport,
        'street_network': navitia_journeys_sections_type_street_network,
        'waiting': navitia_journeys_sections_type_waiting,
        'transfer': navitia_journeys_sections_type_transfer,
    }
    func = switcher_journeys_sections_type.get(json['type'], "Invalid navitia type")
    step = func(json, _id)
    return step

def navitia_journeys_sections_type_public_transport(json, _id=0):
    display_information = json['display_informations']
    label = '{} {} / {} / direction: {}'.format(
        display_information['physical_mode'],
        display_information['code'],
        display_information['name'],
        display_information['direction'],
    )
    step = journey_step(_id, 
                        _type=display_information['network'].lower(),
                        label=label, 
                        distance_m=None, 
                        duration_s=json['duration'],
                        price_EUR=[0],
                        gCO2=json['co2_emission']['value'],
                        geojson=json['geojson'],
                        )
    return step

def navitia_journeys_sections_type_street_network(json, _id=0):
    mode = json['mode']
    mode_to_type = {
        'walking':'walk',
        'bike':'bike',
        'car':'car',
    }
    label = '{} FROM {} TO {}'.format(
        mode_to_type[mode],
        json['from']['name'],
        json['to']['name'],
    )
    step = journey_step(_id, 
                        _type=mode_to_type[mode],
                        label=label, 
                        distance_m=None, 
                        duration_s=json['duration'],
                        price_EUR=[0],
                        gCO2=json['co2_emission']['value'],
                        geojson=json['geojson'],
                        )
    return step

def navitia_journeys_sections_type_transfer(json, _id=0):
    mode = json['transfer_type']
    mode_to_type = {
        'walking':'walk',
        'bike':'bike',
        'car':'car',
    }
    label = '{} FROM {} TO {}'.format(
        mode_to_type[mode],
        json['from']['name'],
        json['to']['name'],
    )
    step = journey_step(_id, 
                        _type=mode_to_type[mode],
                        label=label, 
                        distance_m=None, 
                        duration_s=json['duration'],
                        price_EUR=[0],
                        gCO2=json['co2_emission']['value'],
                        geojson=json['geojson'],
                        )
    return step

def navitia_journeys_sections_type_waiting(json, _id=0):
    step = journey_step(_id, 
                        _type='wait',
                        label='wait', 
                        distance_m=None, 
                        duration_s=json['duration'],
                        price_EUR=[0],
                        gCO2=json['co2_emission']['value'],
                        geojson='',
                        )
    return step

def navitia_journeys_correct(journey, json):
    try:
        if type(j) == journey
    except:
        print('ERROR function navitia_journeys_correct() - INPUT Not journey class')
        return False
    
    return journey

# %% [markdown]
# # Testing

# %%
q = create_query('13 rue Abel','43 Quai Branly')
q
# Out:
# {'query': {'start': {'address': '13 rue Abel', 'coord': [2.37549, 48.847782]},
#   'to': {'address': '43 Quai Branly', 'coord': [2.297232, 48.861317]},
#   'datetime': ''}}

# %%
ORS_query_directions(q,geometry=True)#.plot_map(center=(48.864716,2.349014))

# %%
navitia_response = navitia_query_directions(q)

# %%
def navitia_journey_desc(json, _id=0):
    fare = json['fare']
    print('WARNING Navitia: Journey -->No fare found') if fare['found'] == False else True
    price_EUR = fare['total']['value']/1000
    
    json_step = {'id':_id,
                 'type':'wait',
                 'label':'wait',
                 'distance_m':None,
                 'duration_s':json['duration'],
                 'price_EUR':[price_EUR],
                 'gCO2':json['co2_emission']['value'],
                }
    return json_step

navitia_response['journeys'][0]#['distance']
# Out:
# {'status': '',
#  'distances': {'taxi': 0,
#   'car': 0,
#   'walking': 905,
#   'bike': 0,
#   'ridesharing': 0},
#  'links': [{'href': 'https://api.navitia.io/v1/coverage/fr-idf/journeys?from=2.37549%3B48.847782&last_section_mode%5B%5D=walking&is_journey_schedules=True&direct_path=none&to=2.297232%3B48.861317&min_nb_journeys=5&min_nb_transfers=1&allowed_id%5B%5D=stop_point%3A0%3ASP%3A59232&allowed_id%5B%5D=stop_point%3A0%3ASP%3A59233&allowed_id%5B%5D=stop_point%3A0%3ASP%3A59249&allowed_id%5B%5D=stop_point%3A0%3ASP%3A59500&first_section_mode%5B%5D=walking',
#    'type': 'journeys',
#    'rel': 'same_journey_schedules',
#    'templated': False}],
#  'tags': ['walking', 'ecologic'],
#  'nb_transfers': 1,
#  'durations': {'taxi': 0,
#   'walking': 1061,
#   'car': 0,
#   'ridesharing': 0,
#   'bike': 0,
#   'total': 2309},
#  'arrival_date_time': '20191013T123133',
#  'calendars': [{'active_periods': [{'begin': '20191013', 'end': '20191021'}],
#    'week_pattern': {'monday': False,
#     'tuesday': False,
#     'friday': False,
#     'wednesday': False,
#     'thursday': False,
#     'sunday': True,
#     'saturday': False}}],
#  'departure_date_time': '20191013T115304',
#  'requested_date_time': '20191013T115045',
#  'fare': {'found': True,
#   'total': {'currency': 'centime', 'value': '190.0'},
#   'links': [{'internal': True,
#     'type': 'ticket',
#     'id': 'ticket_11_0',
#     'rel': 'tickets',
#     'templated': False}]},
#  'co2_emission': {'value': 19.134, 'unit': 'gEC'},
#  'type': 'best',
#  'duration': 2309,
#  'sections': [{'from': {'embedded_type': 'address',
#     'distance': '0',
#     'name': '13 Rue Abel (Paris)',
#     'address': {'name': '13 Rue Abel',
#      'house_number': 13,
#      'coord': {'lat': '48.847781', 'lon': '2.37549'},
#      'label': '13 Rue Abel (Paris)',
#      'administrative_regions': [{'insee': '7511248',
#        'name': 'Quartier des Quinze-Vingts',
#        'level': 10,
#        'coord': {'lat': '48.8469184743', 'lon': '2.37440056912'},
#        'label': 'Quartier des Quinze-Vingts (75012), Paris 12e Arrondissement, Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:2192616',
#        'zip_code': '75012'},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Paris (75000-75116), Île-de-France, France',
#        'id': 'admin:fr:75056',
#        'zip_code': '75000-75116'},
#       {'insee': '75',
#        'name': 'Paris',
#        'level': 6,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:71525'},
#       {'insee': '11',
#        'name': 'Île-de-France',
#        'level': 4,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Île-de-France, France',
#        'id': 'admin:osm:relation:8649'},
#       {'insee': '',
#        'name': 'France',
#        'level': 2,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'France',
#        'id': 'admin:osm:relation:2202162'},
#       {'insee': '75112',
#        'name': 'Paris 12e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.8396154', 'lon': '2.3957517'},
#        'label': 'Paris 12e Arrondissement (75012), Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:9525',
#        'zip_code': '75012'}],
#      'id': '2.37549;48.847781'},
#     'quality': 0,
#     'id': '2.37549;48.847781'},
#    'links': [],
#    'arrival_date_time': '20191013T115800',
#    'co2_emission': {'value': 0.0, 'unit': ''},
#    'to': {'embedded_type': 'stop_point',
#     'stop_point': {'commercial_modes': [{'id': 'commercial_mode:Metro',
#        'name': 'Métro'}],
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '8768600'},
#        {'type': 'source', 'value': '8768600'}],
#       'name': 'Gare de Lyon',
#       'links': [],
#       'coord': {'lat': '48.845057', 'lon': '2.37276'},
#       'label': 'Gare de Lyon (Paris)',
#       'administrative_regions': [{'insee': '7511248',
#         'name': 'Quartier des Quinze-Vingts',
#         'level': 10,
#         'coord': {'lat': '48.846918', 'lon': '2.3744'},
#         'label': 'Quartier des Quinze-Vingts',
#         'id': 'admin:fr:7511248',
#         'zip_code': ''},
#        {'insee': '75056',
#         'name': 'Paris',
#         'level': 8,
#         'coord': {'lat': '48.856696', 'lon': '2.351461'},
#         'label': 'Paris',
#         'id': 'admin:fr:75056',
#         'zip_code': ''},
#        {'insee': '75112',
#         'name': 'Paris 12e Arrondissement',
#         'level': 9,
#         'coord': {'lat': '48.839615', 'lon': '2.395751'},
#         'label': 'Paris 12e Arrondissement',
#         'id': 'admin:fr:75112',
#         'zip_code': ''}],
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:8768600'},
#      'links': [],
#      'physical_modes': [{'id': 'physical_mode:Metro', 'name': 'Métro'}],
#      'coord': {'lat': '48.84556', 'lon': '2.373449'},
#      'label': 'Gare de Lyon (Paris)',
#      'equipments': [],
#      'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463197'},
#       {'type': 'external_code', 'value': '59233'},
#       {'type': 'source', 'value': '59233'}],
#      'administrative_regions': [{'insee': '7511248',
#        'name': 'Quartier des Quinze-Vingts',
#        'level': 10,
#        'coord': {'lat': '48.846918', 'lon': '2.3744'},
#        'label': 'Quartier des Quinze-Vingts',
#        'id': 'admin:fr:7511248',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''},
#       {'insee': '75112',
#        'name': 'Paris 12e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.839615', 'lon': '2.395751'},
#        'label': 'Paris 12e Arrondissement',
#        'id': 'admin:fr:75112',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59233',
#      'name': 'Gare de Lyon'},
#     'quality': 0,
#     'name': 'Gare de Lyon (Paris)',
#     'id': 'stop_point:0:SP:59233'},
#    'departure_date_time': '20191013T115304',
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 331}],
#     'coordinates': [[2.3755705056, 48.8477243569],
#      [2.3755705056, 48.8477243569],
#      [2.375305, 48.847347],
#      [2.375358, 48.847322],
#      [2.375336, 48.847278],
#      [2.37531, 48.847236],
#      [2.375193, 48.847105],
#      [2.375143, 48.847033],
#      [2.375063, 48.846914],
#      [2.374414, 48.845987],
#      [2.374327, 48.845977],
#      [2.373967, 48.845936],
#      [2.373751, 48.845861],
#      [2.373792, 48.845464],
#      [2.3734453503, 48.8455442309],
#      [2.373449, 48.84556]]},
#    'duration': 296,
#    'path': [{'duration': 41, 'direction': 0, 'length': 46, 'name': 'Rue Abel'},
#     {'duration': 4, 'direction': 0, 'length': 4, 'name': 'Avenue Daumesnil'},
#     {'duration': 143, 'direction': 73, 'length': 160, 'name': 'Rue Abel'},
#     {'duration': 28,
#      'direction': 55,
#      'length': 31,
#      'name': 'Boulevard Diderot'},
#     {'duration': 17, 'direction': -18, 'length': 19, 'name': ''},
#     {'duration': 39, 'direction': -66, 'length': 44, 'name': ''},
#     {'duration': 24, 'direction': 0, 'length': 27, 'name': ''}],
#    'type': 'street_network',
#    'id': 'section_36_0',
#    'mode': 'walking'},
#   {'from': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463197'},
#       {'type': 'external_code', 'value': '59233'},
#       {'type': 'source', 'value': '59233'}],
#      'name': 'Gare de Lyon',
#      'links': [],
#      'coord': {'lat': '48.84556', 'lon': '2.373449'},
#      'label': 'Gare de Lyon (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '7511248',
#        'name': 'Quartier des Quinze-Vingts',
#        'level': 10,
#        'coord': {'lat': '48.846918', 'lon': '2.3744'},
#        'label': 'Quartier des Quinze-Vingts',
#        'id': 'admin:fr:7511248',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''},
#       {'insee': '75112',
#        'name': 'Paris 12e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.839615', 'lon': '2.395751'},
#        'label': 'Paris 12e Arrondissement',
#        'id': 'admin:fr:75112',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59233',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '8768600'},
#        {'type': 'source', 'value': '8768600'}],
#       'name': 'Gare de Lyon',
#       'links': [],
#       'coord': {'lat': '48.845057', 'lon': '2.37276'},
#       'label': 'Gare de Lyon (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:8768600'}},
#     'quality': 0,
#     'name': 'Gare de Lyon (Paris)',
#     'id': 'stop_point:0:SP:59233'},
#    'links': [{'type': 'vehicle_journey',
#      'id': 'vehicle_journey:0:108229248-1_dst_2'},
#     {'type': 'line', 'id': 'line:0:100110001:1'},
#     {'type': 'route', 'id': 'route:0:1001100010001A'},
#     {'type': 'commercial_mode', 'id': 'commercial_mode:Metro'},
#     {'type': 'physical_mode', 'id': 'physical_mode:Metro'},
#     {'type': 'network', 'id': 'network:0:439'},
#     {'internal': True,
#      'type': 'ticket',
#      'id': 'ticket_11_0',
#      'rel': 'tickets',
#      'templated': False}],
#    'arrival_date_time': '20191013T121300',
#    'additional_informations': ['regular'],
#    'co2_emission': {'value': 16.707, 'unit': 'gEC'},
#    'display_informations': {'direction': 'La Défense (Grande Arche) (Puteaux)',
#     'code': '1',
#     'network': 'METRO',
#     'links': [],
#     'color': 'FFCD00',
#     'name': 'Château de Vincennes - La Défense',
#     'physical_mode': 'Métro',
#     'headsign': '0:108229248-1_dst_2',
#     'label': '1',
#     'equipments': [],
#     'text_color': '000000',
#     'commercial_mode': 'Métro',
#     'description': ''},
#    'to': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463181'},
#       {'type': 'external_code', 'value': '59232'},
#       {'type': 'source', 'value': '59232'}],
#      'name': 'Franklin-Roosevelt',
#      'links': [],
#      'coord': {'lat': '48.86901', 'lon': '2.310253'},
#      'label': 'Franklin-Roosevelt (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75108',
#        'name': 'Paris 8e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.877315', 'lon': '2.317261'},
#        'label': 'Paris 8e Arrondissement',
#        'id': 'admin:fr:75108',
#        'zip_code': ''},
#       {'insee': '7510829',
#        'name': 'Quartier des Champs-Élysées',
#        'level': 10,
#        'coord': {'lat': '48.867076', 'lon': '2.308649'},
#        'label': 'Quartier des Champs-Élysées',
#        'id': 'admin:fr:7510829',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59232',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59232'},
#        {'type': 'source', 'value': '59232'}],
#       'name': 'Franklin D. Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.86907', 'lon': '2.310002'},
#       'label': 'Franklin D. Roosevelt (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59232'}},
#     'quality': 0,
#     'name': 'Franklin-Roosevelt (Paris)',
#     'id': 'stop_point:0:SP:59232'},
#    'base_arrival_date_time': '20191013T121300',
#    'base_departure_date_time': '20191013T115800',
#    'departure_date_time': '20191013T115800',
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 5569}],
#     'coordinates': [[2.373449, 48.84556],
#      [2.369219, 48.852976],
#      [2.361334, 48.855134],
#      [2.352074, 48.857356],
#      [2.347933, 48.85857],
#      [2.340973, 48.86088],
#      [2.336574, 48.862372],
#      [2.329095, 48.86478],
#      [2.321194, 48.865678],
#      [2.314123, 48.867744],
#      [2.310253, 48.86901]]},
#    'duration': 900,
#    'type': 'public_transport',
#    'id': 'section_37_0',
#    'data_freshness': 'base_schedule',
#    'stop_date_times': [{'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A',
#         'value': '463197'},
#        {'type': 'external_code', 'value': '59233'},
#        {'type': 'source', 'value': '59233'}],
#       'name': 'Gare de Lyon',
#       'links': [],
#       'coord': {'lat': '48.84556', 'lon': '2.373449'},
#       'label': 'Gare de Lyon (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59233'},
#      'links': [],
#      'arrival_date_time': '20191013T115800',
#      'additional_informations': [],
#      'departure_date_time': '20191013T115800',
#      'base_arrival_date_time': '20191013T115800',
#      'base_departure_date_time': '20191013T115800'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '22089'},
#        {'type': 'external_code', 'value': '59238'},
#        {'type': 'source', 'value': '59238'}],
#       'name': 'Bastille',
#       'links': [],
#       'coord': {'lat': '48.852976', 'lon': '2.369219'},
#       'label': 'Bastille (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59238'},
#      'links': [],
#      'arrival_date_time': '20191013T120100',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120100',
#      'base_arrival_date_time': '20191013T120100',
#      'base_departure_date_time': '20191013T120100'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463307'},
#        {'type': 'external_code', 'value': '59225'},
#        {'type': 'source', 'value': '59225'}],
#       'name': 'Saint-Paul (le Marais)',
#       'links': [],
#       'coord': {'lat': '48.855134', 'lon': '2.361334'},
#       'label': 'Saint-Paul (le Marais) (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59225'},
#      'links': [],
#      'arrival_date_time': '20191013T120300',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120300',
#      'base_arrival_date_time': '20191013T120300',
#      'base_departure_date_time': '20191013T120300'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '22091'},
#        {'type': 'external_code', 'value': '59590'},
#        {'type': 'source', 'value': '59590'}],
#       'name': 'Hôtel de Ville',
#       'links': [],
#       'coord': {'lat': '48.857356', 'lon': '2.352074'},
#       'label': 'Hôtel de Ville (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59590'},
#      'links': [],
#      'arrival_date_time': '20191013T120400',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120400',
#      'base_arrival_date_time': '20191013T120400',
#      'base_departure_date_time': '20191013T120400'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463160'},
#        {'type': 'external_code', 'value': '59585'},
#        {'type': 'source', 'value': '59585'}],
#       'name': 'Châtelet',
#       'links': [],
#       'coord': {'lat': '48.85857', 'lon': '2.347933'},
#       'label': 'Châtelet (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59585'},
#      'links': [],
#      'arrival_date_time': '20191013T120600',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120600',
#      'base_arrival_date_time': '20191013T120600',
#      'base_departure_date_time': '20191013T120600'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463218'},
#        {'type': 'external_code', 'value': '59231'},
#        {'type': 'source', 'value': '59231'}],
#       'name': 'Louvre-Rivoli',
#       'links': [],
#       'coord': {'lat': '48.86088', 'lon': '2.340973'},
#       'label': 'Louvre-Rivoli (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59231'},
#      'links': [],
#      'arrival_date_time': '20191013T120700',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120700',
#      'base_arrival_date_time': '20191013T120700',
#      'base_departure_date_time': '20191013T120700'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463227'},
#        {'type': 'external_code', 'value': '59591'},
#        {'type': 'source', 'value': '59591'}],
#       'name': 'Palais-Royal (Musée du Louvre)',
#       'links': [],
#       'coord': {'lat': '48.862372', 'lon': '2.336574'},
#       'label': 'Palais-Royal (Musée du Louvre) (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59591'},
#      'links': [],
#      'arrival_date_time': '20191013T120800',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120800',
#      'base_arrival_date_time': '20191013T120800',
#      'base_departure_date_time': '20191013T120800'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '22075'},
#        {'type': 'external_code', 'value': '59226'},
#        {'type': 'source', 'value': '59226'}],
#       'name': 'Tuileries',
#       'links': [],
#       'coord': {'lat': '48.86478', 'lon': '2.329095'},
#       'label': 'Tuileries (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59226'},
#      'links': [],
#      'arrival_date_time': '20191013T120900',
#      'additional_informations': [],
#      'departure_date_time': '20191013T120900',
#      'base_arrival_date_time': '20191013T120900',
#      'base_departure_date_time': '20191013T120900'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463150'},
#        {'type': 'external_code', 'value': '59235'},
#        {'type': 'source', 'value': '59235'}],
#       'name': 'Concorde',
#       'links': [],
#       'coord': {'lat': '48.865678', 'lon': '2.321194'},
#       'label': 'Concorde (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59235'},
#      'links': [],
#      'arrival_date_time': '20191013T121000',
#      'additional_informations': [],
#      'departure_date_time': '20191013T121000',
#      'base_arrival_date_time': '20191013T121000',
#      'base_departure_date_time': '20191013T121000'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463010'},
#        {'type': 'external_code', 'value': '59592'},
#        {'type': 'source', 'value': '59592'}],
#       'name': 'Champs-Elysées-Clémenceau',
#       'links': [],
#       'coord': {'lat': '48.867744', 'lon': '2.314123'},
#       'label': 'Champs-Elysées-Clémenceau (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59592'},
#      'links': [],
#      'arrival_date_time': '20191013T121200',
#      'additional_informations': [],
#      'departure_date_time': '20191013T121200',
#      'base_arrival_date_time': '20191013T121200',
#      'base_departure_date_time': '20191013T121200'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463181'},
#        {'type': 'external_code', 'value': '59232'},
#        {'type': 'source', 'value': '59232'}],
#       'name': 'Franklin-Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.86901', 'lon': '2.310253'},
#       'label': 'Franklin-Roosevelt (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59232'},
#      'links': [],
#      'arrival_date_time': '20191013T121300',
#      'additional_informations': [],
#      'departure_date_time': '20191013T121300',
#      'base_arrival_date_time': '20191013T121300',
#      'base_departure_date_time': '20191013T121300'}]},
#   {'from': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463181'},
#       {'type': 'external_code', 'value': '59232'},
#       {'type': 'source', 'value': '59232'}],
#      'name': 'Franklin-Roosevelt',
#      'links': [],
#      'coord': {'lat': '48.86901', 'lon': '2.310253'},
#      'label': 'Franklin-Roosevelt (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75108',
#        'name': 'Paris 8e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.877315', 'lon': '2.317261'},
#        'label': 'Paris 8e Arrondissement',
#        'id': 'admin:fr:75108',
#        'zip_code': ''},
#       {'insee': '7510829',
#        'name': 'Quartier des Champs-Élysées',
#        'level': 10,
#        'coord': {'lat': '48.867076', 'lon': '2.308649'},
#        'label': 'Quartier des Champs-Élysées',
#        'id': 'admin:fr:7510829',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59232',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59232'},
#        {'type': 'source', 'value': '59232'}],
#       'name': 'Franklin D. Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.86907', 'lon': '2.310002'},
#       'label': 'Franklin D. Roosevelt (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59232'}},
#     'quality': 0,
#     'name': 'Franklin-Roosevelt (Paris)',
#     'id': 'stop_point:0:SP:59232'},
#    'links': [],
#    'arrival_date_time': '20191013T121712',
#    'co2_emission': {'value': 0.0, 'unit': ''},
#    'to': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463180'},
#       {'type': 'external_code', 'value': '59249'},
#       {'type': 'source', 'value': '59249'}],
#      'name': 'Franklin-Roosevelt',
#      'links': [],
#      'coord': {'lat': '48.868813', 'lon': '2.309926'},
#      'label': 'Franklin-Roosevelt (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75108',
#        'name': 'Paris 8e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.877315', 'lon': '2.317261'},
#        'label': 'Paris 8e Arrondissement',
#        'id': 'admin:fr:75108',
#        'zip_code': ''},
#       {'insee': '7510829',
#        'name': 'Quartier des Champs-Élysées',
#        'level': 10,
#        'coord': {'lat': '48.867076', 'lon': '2.308649'},
#        'label': 'Quartier des Champs-Élysées',
#        'id': 'admin:fr:7510829',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59249',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59232'},
#        {'type': 'source', 'value': '59232'}],
#       'name': 'Franklin D. Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.86907', 'lon': '2.310002'},
#       'label': 'Franklin D. Roosevelt (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59232'}},
#     'quality': 0,
#     'name': 'Franklin-Roosevelt (Paris)',
#     'id': 'stop_point:0:SP:59249'},
#    'departure_date_time': '20191013T121300',
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 32}],
#     'coordinates': [[2.310253, 48.86901], [2.309926, 48.868813]]},
#    'duration': 252,
#    'transfer_type': 'walking',
#    'type': 'transfer',
#    'id': 'section_38_0'},
#   {'links': [],
#    'arrival_date_time': '20191013T122200',
#    'co2_emission': {'value': 0.0, 'unit': ''},
#    'departure_date_time': '20191013T121712',
#    'duration': 288,
#    'type': 'waiting',
#    'id': 'section_39_0'},
#   {'from': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463180'},
#       {'type': 'external_code', 'value': '59249'},
#       {'type': 'source', 'value': '59249'}],
#      'name': 'Franklin-Roosevelt',
#      'links': [],
#      'coord': {'lat': '48.868813', 'lon': '2.309926'},
#      'label': 'Franklin-Roosevelt (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75108',
#        'name': 'Paris 8e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.877315', 'lon': '2.317261'},
#        'label': 'Paris 8e Arrondissement',
#        'id': 'admin:fr:75108',
#        'zip_code': ''},
#       {'insee': '7510829',
#        'name': 'Quartier des Champs-Élysées',
#        'level': 10,
#        'coord': {'lat': '48.867076', 'lon': '2.308649'},
#        'label': 'Quartier des Champs-Élysées',
#        'id': 'admin:fr:7510829',
#        'zip_code': ''},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59249',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59232'},
#        {'type': 'source', 'value': '59232'}],
#       'name': 'Franklin D. Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.86907', 'lon': '2.310002'},
#       'label': 'Franklin D. Roosevelt (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59232'}},
#     'quality': 0,
#     'name': 'Franklin-Roosevelt (Paris)',
#     'id': 'stop_point:0:SP:59249'},
#    'links': [{'type': 'vehicle_journey',
#      'id': 'vehicle_journey:0:108211525-1'},
#     {'type': 'line', 'id': 'line:0:100110009:9'},
#     {'type': 'route', 'id': 'route:0:1001100090001R'},
#     {'type': 'commercial_mode', 'id': 'commercial_mode:Metro'},
#     {'type': 'physical_mode', 'id': 'physical_mode:Metro'},
#     {'type': 'network', 'id': 'network:0:439'},
#     {'internal': True,
#      'type': 'ticket',
#      'id': 'ticket_11_0',
#      'rel': 'tickets',
#      'templated': False}],
#    'arrival_date_time': '20191013T122300',
#    'additional_informations': ['regular'],
#    'co2_emission': {'value': 2.427, 'unit': 'gEC'},
#    'display_informations': {'direction': 'Pont de Sèvres (Boulogne-Billancourt)',
#     'code': '9',
#     'network': 'METRO',
#     'links': [],
#     'color': 'B6BD00',
#     'name': 'Pont de Sèvres - Mairie de Montreuil',
#     'physical_mode': 'Métro',
#     'headsign': '0:108211525-1',
#     'label': '9',
#     'equipments': [],
#     'text_color': '000000',
#     'commercial_mode': 'Métro',
#     'description': ''},
#    'to': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463052'},
#       {'type': 'external_code', 'value': '59500'},
#       {'type': 'source', 'value': '59500'}],
#      'name': 'Alma-Marceau',
#      'links': [],
#      'coord': {'lat': '48.864299', 'lon': '2.301251'},
#      'label': 'Alma-Marceau (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75116',
#        'name': 'Paris 16e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.86317', 'lon': '2.275764'},
#        'label': 'Paris 16e Arrondissement (75016-75116)',
#        'id': 'admin:fr:75116',
#        'zip_code': '75016;75116'},
#       {'insee': '7511664',
#        'name': 'Quartier de Chaillot',
#        'level': 10,
#        'coord': {'lat': '48.868434', 'lon': '2.291677'},
#        'label': 'Quartier de Chaillot (75016-75116)',
#        'id': 'admin:fr:7511664',
#        'zip_code': '75016;75116'},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59500',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59500'},
#        {'type': 'source', 'value': '59500'}],
#       'name': 'Alma / Marceau',
#       'links': [],
#       'coord': {'lat': '48.864756', 'lon': '2.301679'},
#       'label': 'Alma / Marceau (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59500'}},
#     'quality': 0,
#     'name': 'Alma-Marceau (Paris)',
#     'id': 'stop_point:0:SP:59500'},
#    'base_arrival_date_time': '20191013T122300',
#    'base_departure_date_time': '20191013T122200',
#    'departure_date_time': '20191013T122200',
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 809}],
#     'coordinates': [[2.309926, 48.868813], [2.301251, 48.864299]]},
#    'duration': 60,
#    'type': 'public_transport',
#    'id': 'section_40_0',
#    'data_freshness': 'base_schedule',
#    'stop_date_times': [{'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A',
#         'value': '463180'},
#        {'type': 'external_code', 'value': '59249'},
#        {'type': 'source', 'value': '59249'}],
#       'name': 'Franklin-Roosevelt',
#       'links': [],
#       'coord': {'lat': '48.868813', 'lon': '2.309926'},
#       'label': 'Franklin-Roosevelt (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59249'},
#      'links': [],
#      'arrival_date_time': '20191013T122200',
#      'additional_informations': [],
#      'departure_date_time': '20191013T122200',
#      'base_arrival_date_time': '20191013T122200',
#      'base_departure_date_time': '20191013T122200'},
#     {'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463052'},
#        {'type': 'external_code', 'value': '59500'},
#        {'type': 'source', 'value': '59500'}],
#       'name': 'Alma-Marceau',
#       'links': [],
#       'coord': {'lat': '48.864299', 'lon': '2.301251'},
#       'label': 'Alma-Marceau (Paris)',
#       'equipments': [],
#       'fare_zone': {'name': '1'},
#       'id': 'stop_point:0:SP:59500'},
#      'links': [],
#      'arrival_date_time': '20191013T122300',
#      'additional_informations': [],
#      'departure_date_time': '20191013T122300',
#      'base_arrival_date_time': '20191013T122300',
#      'base_departure_date_time': '20191013T122300'}]},
#   {'from': {'embedded_type': 'stop_point',
#     'stop_point': {'codes': [{'type': 'ZDEr_ID_REF_A', 'value': '463052'},
#       {'type': 'external_code', 'value': '59500'},
#       {'type': 'source', 'value': '59500'}],
#      'name': 'Alma-Marceau',
#      'links': [],
#      'coord': {'lat': '48.864299', 'lon': '2.301251'},
#      'label': 'Alma-Marceau (Paris)',
#      'equipments': [],
#      'administrative_regions': [{'insee': '75116',
#        'name': 'Paris 16e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.86317', 'lon': '2.275764'},
#        'label': 'Paris 16e Arrondissement (75016-75116)',
#        'id': 'admin:fr:75116',
#        'zip_code': '75016;75116'},
#       {'insee': '7511664',
#        'name': 'Quartier de Chaillot',
#        'level': 10,
#        'coord': {'lat': '48.868434', 'lon': '2.291677'},
#        'label': 'Quartier de Chaillot (75016-75116)',
#        'id': 'admin:fr:7511664',
#        'zip_code': '75016;75116'},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.856696', 'lon': '2.351461'},
#        'label': 'Paris',
#        'id': 'admin:fr:75056',
#        'zip_code': ''}],
#      'fare_zone': {'name': '1'},
#      'id': 'stop_point:0:SP:59500',
#      'stop_area': {'codes': [{'type': 'external_code', 'value': '59500'},
#        {'type': 'source', 'value': '59500'}],
#       'name': 'Alma / Marceau',
#       'links': [],
#       'coord': {'lat': '48.864756', 'lon': '2.301679'},
#       'label': 'Alma / Marceau (Paris)',
#       'timezone': 'Europe/Paris',
#       'id': 'stop_area:0:SA:59500'}},
#     'quality': 0,
#     'name': 'Alma-Marceau (Paris)',
#     'id': 'stop_point:0:SP:59500'},
#    'links': [],
#    'arrival_date_time': '20191013T123133',
#    'co2_emission': {'value': 0.0, 'unit': ''},
#    'to': {'embedded_type': 'address',
#     'distance': '0',
#     'name': '43 Quai Branly (Paris)',
#     'address': {'name': '43 Quai Branly',
#      'house_number': 43,
#      'coord': {'lat': '48.861316', 'lon': '2.297232'},
#      'label': '43 Quai Branly (Paris)',
#      'administrative_regions': [{'insee': '7510728',
#        'name': 'Quartier du Gros-Caillou',
#        'level': 10,
#        'coord': {'lat': '48.8583005285', 'lon': '2.30153852025'},
#        'label': 'Quartier du Gros-Caillou (75007), Paris 7e Arrondissement, Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:2188569',
#        'zip_code': '75007'},
#       {'insee': '75056',
#        'name': 'Paris',
#        'level': 8,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Paris (75000-75116), Île-de-France, France',
#        'id': 'admin:fr:75056',
#        'zip_code': '75000-75116'},
#       {'insee': '75',
#        'name': 'Paris',
#        'level': 6,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:71525'},
#       {'insee': '11',
#        'name': 'Île-de-France',
#        'level': 4,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'Île-de-France, France',
#        'id': 'admin:osm:relation:8649'},
#       {'insee': '',
#        'name': 'France',
#        'level': 2,
#        'coord': {'lat': '48.8566969', 'lon': '2.3514616'},
#        'label': 'France',
#        'id': 'admin:osm:relation:2202162'},
#       {'insee': '75107',
#        'name': 'Paris 7e Arrondissement',
#        'level': 9,
#        'coord': {'lat': '48.8570281', 'lon': '2.3201953'},
#        'label': 'Paris 7e Arrondissement (75007), Paris, Île-de-France, France',
#        'id': 'admin:osm:relation:9521',
#        'zip_code': '75007'}],
#      'id': '2.297232;48.861316'},
#     'quality': 0,
#     'id': '2.297232;48.861316'},
#    'departure_date_time': '20191013T122300',
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 574}],
#     'coordinates': [[2.301251, 48.864299],
#      [2.3012330578, 48.8642591493],
#      [2.30134, 48.864211],
#      [2.301296, 48.864183],
#      [2.301329, 48.864142],
#      [2.301348, 48.864099],
#      [2.301565, 48.864096],
#      [2.301571, 48.864073],
#      [2.301572, 48.864055],
#      [2.301683, 48.862816],
#      [2.301665, 48.862651],
#      [2.301502, 48.862641],
#      [2.301206, 48.862427],
#      [2.301204, 48.862378],
#      [2.30121, 48.862317],
#      [2.301212, 48.862256],
#      [2.299006, 48.861972],
#      [2.298786, 48.861919],
#      [2.298802, 48.861883],
#      [2.297731, 48.861568],
#      [2.2972282315, 48.8613237574],
#      [2.2972282315, 48.8613237574]]},
#    'duration': 513,
#    'path': [{'duration': 12,
#      'direction': 0,
#      'length': 13,
#      'name': 'Place Maria Callas'},
#     {'duration': 8, 'direction': -74, 'length': 9, 'name': "Place de l'Alma"},
#     {'duration': 14,
#      'direction': -73,
#      'length': 16,
#      'name': 'Avenue de New York'},
#     {'duration': 142,
#      'direction': 79,
#      'length': 159,
#      'name': "Pont de l'Alma"},
#     {'duration': 44, 'direction': 81, 'length': 49, 'name': ''},
#     {'duration': 12, 'direction': -5, 'length': 13, 'name': ''},
#     {'duration': 162, 'direction': 80, 'length': 181, 'name': 'Quai Branly'},
#     {'duration': 3, 'direction': -86, 'length': 3, 'name': ''},
#     {'duration': 116, 'direction': 82, 'length': 130, 'name': 'Quai Branly'}],
#    'type': 'street_network',
#    'id': 'section_41_0',
#    'mode': 'walking'}]}

# %%
#navitia_response['journeys'][0]['sections'][2].keys()#['mode']#.keys()
navitia_journeys(navitia_response)
navitia_journeys_sections_type_public_transport(navitia_response['journeys'][0]['sections'][1]).to_json()
#navitia_response['journeys'][0]['sections'][1]['geojson']
# Out:
# {'id': 0,
#  'type': 'metro',
#  'label': 'Métro 1 / Château de Vincennes - La Défense / direction: La Défense (Grande Arche) (Puteaux)',
#  'distance_m': None,
#  'duration_s': 900,
#  'price_EUR': [0],
#  'gCO2': 16.707,
#  'geojson': {'type': 'LineString',
#   'properties': [{'length': 5569}],
#   'coordinates': [[2.373449, 48.84556],
#    [2.369219, 48.852976],
#    [2.361334, 48.855134],
#    [2.352074, 48.857356],
#    [2.347933, 48.85857],
#    [2.340973, 48.86088],
#    [2.336574, 48.862372],
#    [2.329095, 48.86478],
#    [2.321194, 48.865678],
#    [2.314123, 48.867744],
#    [2.310253, 48.86901]]}}

# %%
steps = navitia_journeys(navitia_response)[0]
j = journey(0, steps=steps)
j.update()
j.to_json()
# Out:
# {'id': 0,
#  'label': '',
#  'score': 0,
#  'total_distance': 0,
#  'total_duration': 2309,
#  'total_price_EUR': 0,
#  'total_gCO2': 19.134,
#  'journey': [{'id': 0,
#    'type': 'walk',
#    'label': 'walk FROM 13 Rue Abel (Paris) TO Gare de Lyon (Paris)',
#    'distance_m': None,
#    'duration_s': 296,
#    'price_EUR': [0],
#    'gCO2': 0.0,
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 331}],
#     'coordinates': [[2.3755705056, 48.8477243569],
#      [2.3755705056, 48.8477243569],
#      [2.375305, 48.847347],
#      [2.375358, 48.847322],
#      [2.375336, 48.847278],
#      [2.37531, 48.847236],
#      [2.375193, 48.847105],
#      [2.375143, 48.847033],
#      [2.375063, 48.846914],
#      [2.374414, 48.845987],
#      [2.374327, 48.845977],
#      [2.373967, 48.845936],
#      [2.373751, 48.845861],
#      [2.373792, 48.845464],
#      [2.3734453503, 48.8455442309],
#      [2.373449, 48.84556]]}},
#   {'id': 1,
#    'type': 'metro',
#    'label': 'Métro 1 / Château de Vincennes - La Défense / direction: La Défense (Grande Arche) (Puteaux)',
#    'distance_m': None,
#    'duration_s': 900,
#    'price_EUR': [0],
#    'gCO2': 16.707,
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 5569}],
#     'coordinates': [[2.373449, 48.84556],
#      [2.369219, 48.852976],
#      [2.361334, 48.855134],
#      [2.352074, 48.857356],
#      [2.347933, 48.85857],
#      [2.340973, 48.86088],
#      [2.336574, 48.862372],
#      [2.329095, 48.86478],
#      [2.321194, 48.865678],
#      [2.314123, 48.867744],
#      [2.310253, 48.86901]]}},
#   {'id': 2,
#    'type': 'walk',
#    'label': 'walk FROM Franklin-Roosevelt (Paris) TO Franklin-Roosevelt (Paris)',
#    'distance_m': None,
#    'duration_s': 252,
#    'price_EUR': [0],
#    'gCO2': 0.0,
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 32}],
#     'coordinates': [[2.310253, 48.86901], [2.309926, 48.868813]]}},
#   {'id': 3,
#    'type': 'wait',
#    'label': 'wait',
#    'distance_m': None,
#    'duration_s': 288,
#    'price_EUR': [0],
#    'gCO2': 0.0,
#    'geojson': ''},
#   {'id': 4,
#    'type': 'metro',
#    'label': 'Métro 9 / Pont de Sèvres - Mairie de Montreuil / direction: Pont de Sèvres (Boulogne-Billancourt)',
#    'distance_m': None,
#    'duration_s': 60,
#    'price_EUR': [0],
#    'gCO2': 2.427,
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 809}],
#     'coordinates': [[2.309926, 48.868813], [2.301251, 48.864299]]}},
#   {'id': 5,
#    'type': 'walk',
#    'label': 'walk FROM Alma-Marceau (Paris) TO 43 Quai Branly (Paris)',
#    'distance_m': None,
#    'duration_s': 513,
#    'price_EUR': [0],
#    'gCO2': 0.0,
#    'geojson': {'type': 'LineString',
#     'properties': [{'length': 574}],
#     'coordinates': [[2.301251, 48.864299],
#      [2.3012330578, 48.8642591493],
#      [2.30134, 48.864211],
#      [2.301296, 48.864183],
#      [2.301329, 48.864142],
#      [2.301348, 48.864099],
#      [2.301565, 48.864096],
#      [2.301571, 48.864073],
#      [2.301572, 48.864055],
#      [2.301683, 48.862816],
#      [2.301665, 48.862651],
#      [2.301502, 48.862641],
#      [2.301206, 48.862427],
#      [2.301204, 48.862378],
#      [2.30121, 48.862317],
#      [2.301212, 48.862256],
#      [2.299006, 48.861972],
#      [2.298786, 48.861919],
#      [2.298802, 48.861883],
#      [2.297731, 48.861568],
#      [2.2972282315, 48.8613237574],
#      [2.2972282315, 48.8613237574]]}}]}

# %%
steps = navitia_journeys(navitia_response)[0]
steps[1].plot_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
navitia_response[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-23448d4d0b65> in <module>
# ----> 1 navitia_response[0]
#
# KeyError: 0
